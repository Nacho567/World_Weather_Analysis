# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.00, high=90.00, size=2000)
lngs = np.random.uniform(low=-180.00, high=180.00, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 748

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"] 
        city_description = city_weather["weather"][0]["description"]
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        #pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tuktoyaktuk
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | bengkulu
# Processing Record 4 of Set 1 | klaksvik
# Processing Record 5 of Set 1 | dolores
# Processing Record 6 of Set 1 | paamiut
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | new norfolk
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | east london
# Processing Record 12 of Set 1 | lebu
# Processing Record 13 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 1 | taoudenni
# Processing Record 15 of Set 1 | axim
# Processing Record 16 of Set 1 | makakilo city
# Processing Record 17 of Set 1 | ahipara
# Processing Record 18 of Set 1 | kununurra
# Processing Record 19 of Set 1 | nizhniy tsasuchey
# Processing Record 20 of Set 1 | ust-tsilma
# Processing Record 21 of Set 1 | sao miguel
# Processing Record 22 of Set 1 | leningradskiy
# Processing Record 23 of Set 1 | luderitz
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | lata
# Processing Record 26 of Set 1 | ribeira grande
# Processing Record 27 of Set 1 | georgetown
# Processing Record 28 of Set 1 | rize
# Processing Record 29 of Set 1 | yerbogachen
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | barrow
# Processing Record 32 of Set 1 | ponta do sol
# Processing Record 33 of Set 1 | ilulissat
# Processing Record 34 of Set 1 | pevek
# Processing Record 35 of Set 1 | carnarvon
# Processing Record 36 of Set 1 | mahebourg
# Processing Record 37 of Set 1 | straumen
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | kruisfontein
# Processing Record 40 of Set 1 | hilo
# Processing Record 41 of Set 1 | cidreira
# Processing Record 42 of Set 1 | norman wells
# Processing Record 43 of Set 1 | puerto ayora
# Processing Record 44 of Set 1 | sivakasi
# Processing Record 45 of Set 1 | bluff
# Processing Record 46 of Set 1 | hereford
# Processing Record 47 of Set 1 | tiksi
# Processing Record 48 of Set 1 | ushuaia
# Processing Record 49 of Set 1 | weymouth
# Processing Record 50 of Set 1 | dikson
# Processing Record 1 of Set 2 | gat
# Processing Record 2 of Set 2 | tommot
# Processing Record 3 of Set 2 | hami
# Processing Record 4 of Set 2 | chuy
# Processing Record 5 of Set 2 | umm durman
# City not found. Skipping...
# Processing Record 6 of Set 2 | pangody
# Processing Record 7 of Set 2 | riyadh
# Processing Record 8 of Set 2 | jiuquan
# Processing Record 9 of Set 2 | hobyo
# Processing Record 10 of Set 2 | grand gaube
# Processing Record 11 of Set 2 | araouane
# Processing Record 12 of Set 2 | port alfred
# Processing Record 13 of Set 2 | sigiriya
# Processing Record 14 of Set 2 | fushan
# Processing Record 15 of Set 2 | kavieng
# Processing Record 16 of Set 2 | elmira
# Processing Record 17 of Set 2 | turukhansk
# Processing Record 18 of Set 2 | hofn
# Processing Record 19 of Set 2 | gogrial
# Processing Record 20 of Set 2 | vao
# Processing Record 21 of Set 2 | belyy yar
# Processing Record 22 of Set 2 | taltal
# Processing Record 23 of Set 2 | lompoc
# Processing Record 24 of Set 2 | sinnamary
# Processing Record 25 of Set 2 | saskylakh
# Processing Record 26 of Set 2 | aklavik
# Processing Record 27 of Set 2 | havoysund
# Processing Record 28 of Set 2 | albany
# Processing Record 29 of Set 2 | arraial do cabo
# Processing Record 30 of Set 2 | severo-kurilsk
# Processing Record 31 of Set 2 | divnoye
# Processing Record 32 of Set 2 | yellowknife
# Processing Record 33 of Set 2 | praia da vitoria
# Processing Record 34 of Set 2 | talaya
# Processing Record 35 of Set 2 | tevaitoa
# Processing Record 36 of Set 2 | butaritari
# Processing Record 37 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 2 | bajil
# Processing Record 39 of Set 2 | bethel
# Processing Record 40 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 2 | maxixe
# Processing Record 42 of Set 2 | dingle
# Processing Record 43 of Set 2 | bambous virieux
# Processing Record 44 of Set 2 | khatanga
# Processing Record 45 of Set 2 | alofi
# Processing Record 46 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 2 | antofagasta
# Processing Record 48 of Set 2 | gamba
# Processing Record 49 of Set 2 | avarua
# Processing Record 50 of Set 2 | kapaa
# Processing Record 1 of Set 3 | tura
# Processing Record 2 of Set 3 | tabulbah
# City not found. Skipping...
# Processing Record 3 of Set 3 | vallenar
# Processing Record 4 of Set 3 | isangel
# Processing Record 5 of Set 3 | anadyr
# Processing Record 6 of Set 3 | istisu
# Processing Record 7 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 8 of Set 3 | atuona
# Processing Record 9 of Set 3 | necochea
# Processing Record 10 of Set 3 | sauda
# Processing Record 11 of Set 3 | busselton
# Processing Record 12 of Set 3 | taldan
# Processing Record 13 of Set 3 | thompson
# Processing Record 14 of Set 3 | sydney
# Processing Record 15 of Set 3 | samarai
# Processing Record 16 of Set 3 | thinadhoo
# Processing Record 17 of Set 3 | hermanus
# Processing Record 18 of Set 3 | qaqortoq
# Processing Record 19 of Set 3 | kegums
# Processing Record 20 of Set 3 | bredasdorp
# Processing Record 21 of Set 3 | lagoa
# Processing Record 22 of Set 3 | ostrovnoy
# Processing Record 23 of Set 3 | upernavik
# Processing Record 24 of Set 3 | conceicao do araguaia
# Processing Record 25 of Set 3 | puerto del rosario
# Processing Record 26 of Set 3 | koumac
# Processing Record 27 of Set 3 | port blair
# Processing Record 28 of Set 3 | amapa
# Processing Record 29 of Set 3 | cabedelo
# Processing Record 30 of Set 3 | hithadhoo
# Processing Record 31 of Set 3 | tilichiki
# Processing Record 32 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 3 | pisco
# Processing Record 34 of Set 3 | ulladulla
# Processing Record 35 of Set 3 | kattivakkam
# Processing Record 36 of Set 3 | saint-augustin
# Processing Record 37 of Set 3 | vanavara
# Processing Record 38 of Set 3 | baghdad
# Processing Record 39 of Set 3 | upleta
# Processing Record 40 of Set 3 | vila franca do campo
# Processing Record 41 of Set 3 | longyearbyen
# Processing Record 42 of Set 3 | labuhan
# Processing Record 43 of Set 3 | kautokeino
# Processing Record 44 of Set 3 | udachnyy
# Processing Record 45 of Set 3 | souillac
# Processing Record 46 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 3 | baturaja
# Processing Record 48 of Set 3 | castro
# Processing Record 49 of Set 3 | kiunga
# Processing Record 50 of Set 3 | jardim
# Processing Record 1 of Set 4 | huarmey
# Processing Record 2 of Set 4 | buala
# Processing Record 3 of Set 4 | camacha
# Processing Record 4 of Set 4 | jiazi
# Processing Record 5 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 4 | alice springs
# Processing Record 7 of Set 4 | nouakchott
# Processing Record 8 of Set 4 | mastung
# Processing Record 9 of Set 4 | limon
# Processing Record 10 of Set 4 | bubaque
# Processing Record 11 of Set 4 | ixtapa
# Processing Record 12 of Set 4 | tena
# Processing Record 13 of Set 4 | burnie
# Processing Record 14 of Set 4 | faanui
# Processing Record 15 of Set 4 | qaanaaq
# Processing Record 16 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 4 | lumphat
# Processing Record 18 of Set 4 | chaupal
# Processing Record 19 of Set 4 | baft
# Processing Record 20 of Set 4 | eureka
# Processing Record 21 of Set 4 | dafeng
# Processing Record 22 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 4 | matamoros
# Processing Record 24 of Set 4 | provideniya
# Processing Record 25 of Set 4 | talara
# Processing Record 26 of Set 4 | ponerihouen
# Processing Record 27 of Set 4 | buraydah
# Processing Record 28 of Set 4 | hamilton
# Processing Record 29 of Set 4 | san patricio
# Processing Record 30 of Set 4 | mar del plata
# Processing Record 31 of Set 4 | nikolskoye
# Processing Record 32 of Set 4 | esperance
# Processing Record 33 of Set 4 | oakdale
# Processing Record 34 of Set 4 | port-cartier
# Processing Record 35 of Set 4 | bilibino
# Processing Record 36 of Set 4 | kudahuvadhoo
# Processing Record 37 of Set 4 | porto santo
# Processing Record 38 of Set 4 | chokurdakh
# Processing Record 39 of Set 4 | saint-philippe
# Processing Record 40 of Set 4 | ye
# City not found. Skipping...
# Processing Record 41 of Set 4 | kishni
# Processing Record 42 of Set 4 | wattegama
# Processing Record 43 of Set 4 | port elizabeth
# Processing Record 44 of Set 4 | zheshart
# Processing Record 45 of Set 4 | sisimiut
# Processing Record 46 of Set 4 | los llanos de aridane
# Processing Record 47 of Set 4 | khorol
# Processing Record 48 of Set 4 | kirakira
# Processing Record 49 of Set 4 | waipawa
# Processing Record 50 of Set 4 | shiyan
# Processing Record 1 of Set 5 | misratah
# Processing Record 2 of Set 5 | rexburg
# Processing Record 3 of Set 5 | maloy
# Processing Record 4 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 5 | sur
# Processing Record 6 of Set 5 | roblin
# Processing Record 7 of Set 5 | imbituba
# Processing Record 8 of Set 5 | bouake
# Processing Record 9 of Set 5 | rocha
# Processing Record 10 of Set 5 | fortuna
# Processing Record 11 of Set 5 | evans
# Processing Record 12 of Set 5 | dunn
# Processing Record 13 of Set 5 | cairns
# Processing Record 14 of Set 5 | bandarban
# Processing Record 15 of Set 5 | tayshet
# Processing Record 16 of Set 5 | iwanai
# Processing Record 17 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 5 | imeni poliny osipenko
# Processing Record 19 of Set 5 | namatanai
# Processing Record 20 of Set 5 | port lincoln
# Processing Record 21 of Set 5 | mackay
# Processing Record 22 of Set 5 | coahuayana
# Processing Record 23 of Set 5 | bathsheba
# Processing Record 24 of Set 5 | kavaratti
# Processing Record 25 of Set 5 | port macquarie
# Processing Record 26 of Set 5 | belfast
# Processing Record 27 of Set 5 | dhidhdhoo
# Processing Record 28 of Set 5 | nurlat
# Processing Record 29 of Set 5 | atar
# Processing Record 30 of Set 5 | allende
# Processing Record 31 of Set 5 | pilar
# Processing Record 32 of Set 5 | saint-pierre
# Processing Record 33 of Set 5 | hirara
# Processing Record 34 of Set 5 | nanortalik
# Processing Record 35 of Set 5 | xuanzhou
# Processing Record 36 of Set 5 | bom jesus da lapa
# Processing Record 37 of Set 5 | cabo san lucas
# Processing Record 38 of Set 5 | pervomayskoye
# Processing Record 39 of Set 5 | san carlos de bariloche
# Processing Record 40 of Set 5 | omboue
# Processing Record 41 of Set 5 | vardo
# Processing Record 42 of Set 5 | faya
# Processing Record 43 of Set 5 | airai
# Processing Record 44 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 5 | nemuro
# Processing Record 46 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 5 | aykino
# Processing Record 48 of Set 5 | cururupu
# Processing Record 49 of Set 5 | tautira
# Processing Record 50 of Set 5 | kalianget
# Processing Record 1 of Set 6 | salym
# Processing Record 2 of Set 6 | bastia
# Processing Record 3 of Set 6 | olinda
# Processing Record 4 of Set 6 | port-gentil
# Processing Record 5 of Set 6 | honningsvag
# Processing Record 6 of Set 6 | kaitangata
# Processing Record 7 of Set 6 | batouri
# Processing Record 8 of Set 6 | kortkeros
# Processing Record 9 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 10 of Set 6 | laguna
# Processing Record 11 of Set 6 | ola
# Processing Record 12 of Set 6 | hlubocky
# Processing Record 13 of Set 6 | mandera
# Processing Record 14 of Set 6 | clyde river
# Processing Record 15 of Set 6 | torbay
# Processing Record 16 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 6 | oistins
# Processing Record 18 of Set 6 | chapais
# Processing Record 19 of Set 6 | leh
# Processing Record 20 of Set 6 | svetlyy
# Processing Record 21 of Set 6 | trapani
# Processing Record 22 of Set 6 | tazovskiy
# Processing Record 23 of Set 6 | warrnambool
# Processing Record 24 of Set 6 | bafoulabe
# Processing Record 25 of Set 6 | roebourne
# Processing Record 26 of Set 6 | medianeira
# Processing Record 27 of Set 6 | kirillov
# Processing Record 28 of Set 6 | honiara
# Processing Record 29 of Set 6 | kodiak
# Processing Record 30 of Set 6 | librazhd
# Processing Record 31 of Set 6 | lasa
# Processing Record 32 of Set 6 | tahlequah
# Processing Record 33 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 34 of Set 6 | santa rosa
# Processing Record 35 of Set 6 | vostok
# Processing Record 36 of Set 6 | asfi
# Processing Record 37 of Set 6 | high wycombe
# Processing Record 38 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 39 of Set 6 | cherskiy
# Processing Record 40 of Set 6 | ombessa
# Processing Record 41 of Set 6 | tasiilaq
# Processing Record 42 of Set 6 | saint-joseph
# Processing Record 43 of Set 6 | evensk
# Processing Record 44 of Set 6 | tabialan
# City not found. Skipping...
# Processing Record 45 of Set 6 | salalah
# Processing Record 46 of Set 6 | sioux lookout
# Processing Record 47 of Set 6 | northam
# Processing Record 48 of Set 6 | touros
# Processing Record 49 of Set 6 | srednekolymsk
# Processing Record 50 of Set 6 | oranjestad
# Processing Record 1 of Set 7 | flic en flac
# Processing Record 2 of Set 7 | atambua
# Processing Record 3 of Set 7 | seoul
# Processing Record 4 of Set 7 | ancud
# Processing Record 5 of Set 7 | cajati
# Processing Record 6 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 7 of Set 7 | qianan
# Processing Record 8 of Set 7 | victoria
# Processing Record 9 of Set 7 | kiama
# Processing Record 10 of Set 7 | saldanha
# Processing Record 11 of Set 7 | adrar
# Processing Record 12 of Set 7 | kaka
# Processing Record 13 of Set 7 | port shepstone
# Processing Record 14 of Set 7 | olafsvik
# Processing Record 15 of Set 7 | lerwick
# Processing Record 16 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 17 of Set 7 | muros
# Processing Record 18 of Set 7 | fairbanks
# Processing Record 19 of Set 7 | oranjemund
# Processing Record 20 of Set 7 | koungou
# Processing Record 21 of Set 7 | boa vista
# Processing Record 22 of Set 7 | iqaluit
# Processing Record 23 of Set 7 | coari
# Processing Record 24 of Set 7 | madang
# Processing Record 25 of Set 7 | bosaso
# Processing Record 26 of Set 7 | kyaukse
# Processing Record 27 of Set 7 | bahia honda
# Processing Record 28 of Set 7 | nuuk
# Processing Record 29 of Set 7 | grindavik
# Processing Record 30 of Set 7 | north bend
# Processing Record 31 of Set 7 | harper
# Processing Record 32 of Set 7 | sola
# Processing Record 33 of Set 7 | nyagan
# Processing Record 34 of Set 7 | tikhvin
# Processing Record 35 of Set 7 | sao filipe
# Processing Record 36 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 7 | yamada
# Processing Record 38 of Set 7 | tupancireta
# Processing Record 39 of Set 7 | yinchuan
# Processing Record 40 of Set 7 | nishihara
# Processing Record 41 of Set 7 | hambantota
# Processing Record 42 of Set 7 | codrington
# Processing Record 43 of Set 7 | panjab
# Processing Record 44 of Set 7 | livramento
# Processing Record 45 of Set 7 | constitucion
# Processing Record 46 of Set 7 | yulara
# Processing Record 47 of Set 7 | mattru
# Processing Record 48 of Set 7 | inhambane
# Processing Record 49 of Set 7 | bow island
# Processing Record 50 of Set 7 | tres arroyos
# Processing Record 1 of Set 8 | little current
# Processing Record 2 of Set 8 | launceston
# Processing Record 3 of Set 8 | bergen
# Processing Record 4 of Set 8 | trairi
# Processing Record 5 of Set 8 | gryfino
# Processing Record 6 of Set 8 | saint george
# Processing Record 7 of Set 8 | abay
# Processing Record 8 of Set 8 | lahat
# Processing Record 9 of Set 8 | potsdam
# Processing Record 10 of Set 8 | domat
# Processing Record 11 of Set 8 | tual
# Processing Record 12 of Set 8 | syasstroy
# Processing Record 13 of Set 8 | parkersburg
# Processing Record 14 of Set 8 | ogaminana
# Processing Record 15 of Set 8 | grand-santi
# Processing Record 16 of Set 8 | dalbandin
# Processing Record 17 of Set 8 | haines junction
# Processing Record 18 of Set 8 | narsaq
# Processing Record 19 of Set 8 | labytnangi
# Processing Record 20 of Set 8 | kholm
# Processing Record 21 of Set 8 | coquimbo
# Processing Record 22 of Set 8 | asau
# Processing Record 23 of Set 8 | valparaiso
# Processing Record 24 of Set 8 | balad
# Processing Record 25 of Set 8 | tonj
# Processing Record 26 of Set 8 | dinsor
# City not found. Skipping...
# Processing Record 27 of Set 8 | scottsbluff
# Processing Record 28 of Set 8 | charlestown
# Processing Record 29 of Set 8 | buchanan
# Processing Record 30 of Set 8 | yumen
# Processing Record 31 of Set 8 | lichinga
# Processing Record 32 of Set 8 | kitimat
# Processing Record 33 of Set 8 | mwene-ditu
# Processing Record 34 of Set 8 | husavik
# Processing Record 35 of Set 8 | aksha
# Processing Record 36 of Set 8 | bereda
# Processing Record 37 of Set 8 | kerrville
# Processing Record 38 of Set 8 | smithers
# Processing Record 39 of Set 8 | manta
# Processing Record 40 of Set 8 | ahuimanu
# Processing Record 41 of Set 8 | yomitan
# City not found. Skipping...
# Processing Record 42 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 8 | villamontes
# Processing Record 44 of Set 8 | margate
# Processing Record 45 of Set 8 | la ronge
# Processing Record 46 of Set 8 | jalu
# Processing Record 47 of Set 8 | beyneu
# Processing Record 48 of Set 8 | ambilobe
# Processing Record 49 of Set 8 | sindor
# Processing Record 50 of Set 8 | kulhudhuffushi
# Processing Record 1 of Set 9 | umm kaddadah
# Processing Record 2 of Set 9 | magistralnyy
# Processing Record 3 of Set 9 | kirpilskaya
# Processing Record 4 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 9 | mogadishu
# Processing Record 6 of Set 9 | big spring
# Processing Record 7 of Set 9 | kamenka
# Processing Record 8 of Set 9 | vyyezdnoye
# Processing Record 9 of Set 9 | abha
# Processing Record 10 of Set 9 | san cristobal
# Processing Record 11 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 9 | katsuura
# Processing Record 13 of Set 9 | porto walter
# Processing Record 14 of Set 9 | trebnje
# Processing Record 15 of Set 9 | dovers
# Processing Record 16 of Set 9 | deputatskiy
# Processing Record 17 of Set 9 | jimeta
# Processing Record 18 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 19 of Set 9 | svetlogorsk
# Processing Record 20 of Set 9 | ciudad bolivar
# Processing Record 21 of Set 9 | mendahara
# City not found. Skipping...
# Processing Record 22 of Set 9 | college
# Processing Record 23 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 24 of Set 9 | berdigestyakh
# Processing Record 25 of Set 9 | hualmay
# Processing Record 26 of Set 9 | kyshtovka
# Processing Record 27 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 28 of Set 9 | dunedin
# Processing Record 29 of Set 9 | semey
# Processing Record 30 of Set 9 | vodnyy
# Processing Record 31 of Set 9 | karratha
# Processing Record 32 of Set 9 | puerto carreno
# Processing Record 33 of Set 9 | pangnirtung
# Processing Record 34 of Set 9 | ardmore
# Processing Record 35 of Set 9 | henties bay
# Processing Record 36 of Set 9 | changji
# Processing Record 37 of Set 9 | rongcheng
# Processing Record 38 of Set 9 | aasiaat
# Processing Record 39 of Set 9 | hasaki
# Processing Record 40 of Set 9 | robertsport
# Processing Record 41 of Set 9 | namibe
# Processing Record 42 of Set 9 | kahului
# Processing Record 43 of Set 9 | almeirim
# Processing Record 44 of Set 9 | namwala
# Processing Record 45 of Set 9 | bonthe
# Processing Record 46 of Set 9 | goderich
# Processing Record 47 of Set 9 | korla
# Processing Record 48 of Set 9 | aksu
# Processing Record 49 of Set 9 | yar-sale
# Processing Record 50 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 10 | san jeronimo
# Processing Record 2 of Set 10 | aquiraz
# Processing Record 3 of Set 10 | poya
# Processing Record 4 of Set 10 | avera
# Processing Record 5 of Set 10 | tuatapere
# Processing Record 6 of Set 10 | carutapera
# Processing Record 7 of Set 10 | bokhan
# Processing Record 8 of Set 10 | samdari
# Processing Record 9 of Set 10 | prince rupert
# Processing Record 10 of Set 10 | nybro
# Processing Record 11 of Set 10 | vestmannaeyjar
# Processing Record 12 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 10 | tagusao
# Processing Record 14 of Set 10 | calgary
# Processing Record 15 of Set 10 | bo
# City not found. Skipping...
# Processing Record 16 of Set 10 | griffith
# Processing Record 17 of Set 10 | port hedland
# Processing Record 18 of Set 10 | manyana
# Processing Record 19 of Set 10 | rosarito
# Processing Record 20 of Set 10 | guozhen
# Processing Record 21 of Set 10 | saint anthony
# Processing Record 22 of Set 10 | mecca
# Processing Record 23 of Set 10 | gorele
# Processing Record 24 of Set 10 | bud
# Processing Record 25 of Set 10 | kolno
# Processing Record 26 of Set 10 | begunitsy
# Processing Record 27 of Set 10 | acapulco
# Processing Record 28 of Set 10 | mabaruma
# Processing Record 29 of Set 10 | mastic beach
# Processing Record 30 of Set 10 | vila velha
# Processing Record 31 of Set 10 | lucea
# Processing Record 32 of Set 10 | cernisoara
# Processing Record 33 of Set 10 | qui nhon
# Processing Record 34 of Set 10 | along
# Processing Record 35 of Set 10 | edremit
# Processing Record 36 of Set 10 | umarkot
# Processing Record 37 of Set 10 | roald
# Processing Record 38 of Set 10 | stromness
# Processing Record 39 of Set 10 | jacareacanga
# Processing Record 40 of Set 10 | akdepe
# Processing Record 41 of Set 10 | westport
# Processing Record 42 of Set 10 | fayaoue
# Processing Record 43 of Set 10 | ginir
# Processing Record 44 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 45 of Set 10 | yibin
# Processing Record 46 of Set 10 | roma
# Processing Record 47 of Set 10 | sorland
# Processing Record 48 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 49 of Set 10 | formosa
# Processing Record 50 of Set 10 | chemax
# Processing Record 1 of Set 11 | buin
# Processing Record 2 of Set 11 | cuenca
# Processing Record 3 of Set 11 | oskaloosa
# Processing Record 4 of Set 11 | det udom
# Processing Record 5 of Set 11 | nagato
# Processing Record 6 of Set 11 | lavrentiya
# Processing Record 7 of Set 11 | la esperanza
# Processing Record 8 of Set 11 | port hawkesbury
# Processing Record 9 of Set 11 | san rafael
# Processing Record 10 of Set 11 | raga
# Processing Record 11 of Set 11 | bombay
# Processing Record 12 of Set 11 | vysokogornyy
# Processing Record 13 of Set 11 | cockburn town
# Processing Record 14 of Set 11 | wanning
# Processing Record 15 of Set 11 | dandong
# Processing Record 16 of Set 11 | talnakh
# Processing Record 17 of Set 11 | bonito
# Processing Record 18 of Set 11 | bograd
# Processing Record 19 of Set 11 | richards bay
# Processing Record 20 of Set 11 | soavinandriana
# Processing Record 21 of Set 11 | kloulklubed
# Processing Record 22 of Set 11 | shitanjing
# Processing Record 23 of Set 11 | padang
# Processing Record 24 of Set 11 | botshabelo
# Processing Record 25 of Set 11 | ignacio zaragoza
# Processing Record 26 of Set 11 | juifang
# City not found. Skipping...
# Processing Record 27 of Set 11 | angol
# Processing Record 28 of Set 11 | solton
# Processing Record 29 of Set 11 | okhotsk
# Processing Record 30 of Set 11 | impfondo
# Processing Record 31 of Set 11 | kosonsoy
# Processing Record 32 of Set 11 | neiafu
# Processing Record 33 of Set 11 | saint-francois
# Processing Record 34 of Set 11 | ewa beach
# Processing Record 35 of Set 11 | sitka
# Processing Record 36 of Set 11 | yasnaya polyana
# Processing Record 37 of Set 11 | princeton
# Processing Record 38 of Set 11 | marawi
# Processing Record 39 of Set 11 | molochnyy
# Processing Record 40 of Set 11 | moose factory
# Processing Record 41 of Set 11 | klyuchi
# Processing Record 42 of Set 11 | jiaonan
# Processing Record 43 of Set 11 | kawalu
# Processing Record 44 of Set 11 | sarkand
# Processing Record 45 of Set 11 | zeya
# Processing Record 46 of Set 11 | balkhash
# Processing Record 47 of Set 11 | bentiu
# Processing Record 48 of Set 11 | inongo
# Processing Record 49 of Set 11 | teya
# Processing Record 50 of Set 11 | saint-leu
# Processing Record 1 of Set 12 | pavlodar
# Processing Record 2 of Set 12 | lubao
# Processing Record 3 of Set 12 | albacete
# Processing Record 4 of Set 12 | krasnorechenskiy
# Processing Record 5 of Set 12 | skagen
# Processing Record 6 of Set 12 | zhigansk
# Processing Record 7 of Set 12 | aras
# Processing Record 8 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 9 of Set 12 | igrim
# Processing Record 10 of Set 12 | koforidua
# Processing Record 11 of Set 12 | gouyave
# Processing Record 12 of Set 12 | tete
# Processing Record 13 of Set 12 | batsfjord
# Processing Record 14 of Set 12 | venado tuerto
# Processing Record 15 of Set 12 | kamina
# Processing Record 16 of Set 12 | egvekinot
# Processing Record 17 of Set 12 | neftegorsk
# Processing Record 18 of Set 12 | mysliborz
# Processing Record 19 of Set 12 | geraldton
# Processing Record 20 of Set 12 | bucerias
# Processing Record 21 of Set 12 | ayan
# Processing Record 22 of Set 12 | matara
# Processing Record 23 of Set 12 | kegalla
# City not found. Skipping...
# Processing Record 24 of Set 12 | santa marta
# Processing Record 25 of Set 12 | kurilsk
# Processing Record 26 of Set 12 | ugoofaaru
# Processing Record 27 of Set 12 | sujangarh
# Processing Record 28 of Set 12 | arlit
# Processing Record 29 of Set 12 | chaoyang
# Processing Record 30 of Set 12 | gretna
# Processing Record 31 of Set 12 | puerto el triunfo
# Processing Record 32 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 33 of Set 12 | kostomuksha
# Processing Record 34 of Set 12 | chortkiv
# Processing Record 35 of Set 12 | flinders
# Processing Record 36 of Set 12 | sao joao da barra
# Processing Record 37 of Set 12 | urusha
# Processing Record 38 of Set 12 | tlacotepec
# Processing Record 39 of Set 12 | van buren
# Processing Record 40 of Set 12 | hita
# Processing Record 41 of Set 12 | calatayud
# Processing Record 42 of Set 12 | bilma
# Processing Record 43 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 44 of Set 12 | sabaudia
# Processing Record 45 of Set 12 | muroto
# Processing Record 46 of Set 12 | chernyshevskiy
# Processing Record 47 of Set 12 | gazojak
# Processing Record 48 of Set 12 | jiexiu
# Processing Record 49 of Set 12 | nanakuli
# Processing Record 50 of Set 12 | gerash
# Processing Record 1 of Set 13 | rivadavia
# Processing Record 2 of Set 13 | spring valley
# Processing Record 3 of Set 13 | palmas
# Processing Record 4 of Set 13 | quang ngai
# Processing Record 5 of Set 13 | cariamanga
# Processing Record 6 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 7 of Set 13 | myanaung
# Processing Record 8 of Set 13 | kutum
# Processing Record 9 of Set 13 | yueyang
# Processing Record 10 of Set 13 | marsh harbour
# Processing Record 11 of Set 13 | boddam
# Processing Record 12 of Set 13 | lodwar
# Processing Record 13 of Set 13 | pizarro
# Processing Record 14 of Set 13 | mount gambier
# Processing Record 15 of Set 13 | santa isabel do rio negro
# Processing Record 16 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 17 of Set 13 | kaduqli
# Processing Record 18 of Set 13 | erenhot
# Processing Record 19 of Set 13 | oktyabrskiy
# Processing Record 20 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 13 | stykkisholmur
# Processing Record 22 of Set 13 | alappuzha
# Processing Record 23 of Set 13 | new bern
# Processing Record 24 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 25 of Set 13 | jining
# Processing Record 26 of Set 13 | dnipryany
# Processing Record 27 of Set 13 | arman
# Processing Record 28 of Set 13 | rawson
# Processing Record 29 of Set 13 | nouadhibou
# Processing Record 30 of Set 13 | hervey bay
# Processing Record 31 of Set 13 | chissamba
# Processing Record 32 of Set 13 | carman
# Processing Record 33 of Set 13 | sabha
# Processing Record 34 of Set 13 | basoko
# Processing Record 35 of Set 13 | chicama
# Processing Record 36 of Set 13 | lorengau
# Processing Record 37 of Set 13 | povenets
# Processing Record 38 of Set 13 | arkhara
# Processing Record 39 of Set 13 | saint-raymond
# Processing Record 40 of Set 13 | naryan-mar
# Processing Record 41 of Set 13 | pinega
# Processing Record 42 of Set 13 | duz
# City not found. Skipping...
# Processing Record 43 of Set 13 | sai buri
# Processing Record 44 of Set 13 | aswan
# Processing Record 45 of Set 13 | khandyga
# Processing Record 46 of Set 13 | tabuk
# Processing Record 47 of Set 13 | ust-koksa
# Processing Record 48 of Set 13 | carbonia
# Processing Record 49 of Set 13 | aguia branca
# Processing Record 50 of Set 13 | verkhnevilyuysk
# Processing Record 1 of Set 14 | correntina
# Processing Record 2 of Set 14 | vanimo
# Processing Record 3 of Set 14 | ust-nera
# Processing Record 4 of Set 14 | dasoguz
# Processing Record 5 of Set 14 | fort dodge
# Processing Record 6 of Set 14 | champerico
# Processing Record 7 of Set 14 | eyl
# Processing Record 8 of Set 14 | te anau
# Processing Record 9 of Set 14 | puerto quijarro
# Processing Record 10 of Set 14 | nara
# Processing Record 11 of Set 14 | usinsk
# Processing Record 12 of Set 14 | campina verde
# Processing Record 13 of Set 14 | tarbagatay
# Processing Record 14 of Set 14 | calbuco
# Processing Record 15 of Set 14 | christchurch
# Processing Record 16 of Set 14 | burica
# City not found. Skipping...
# Processing Record 17 of Set 14 | bobo dioulasso
# Processing Record 18 of Set 14 | acajutla
# Processing Record 19 of Set 14 | ballina
# Processing Record 20 of Set 14 | itarema
# Processing Record 21 of Set 14 | lufilufi
# Processing Record 22 of Set 14 | breves
# Processing Record 23 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 24 of Set 14 | oxford
# Processing Record 25 of Set 14 | floro
# Processing Record 26 of Set 14 | meulaboh
# Processing Record 27 of Set 14 | pundaguitan
# Processing Record 28 of Set 14 | powell river
# Processing Record 29 of Set 14 | kieta
# Processing Record 30 of Set 14 | vikindu
# Processing Record 31 of Set 14 | porirua
# Processing Record 32 of Set 14 | maarianhamina
# Processing Record 33 of Set 14 | esmeraldas
# Processing Record 34 of Set 14 | cam ranh
# Processing Record 35 of Set 14 | stepnoye
# Processing Record 36 of Set 14 | bismarck
# Processing Record 37 of Set 14 | shelburne
# Processing Record 38 of Set 14 | aleksandrov gay
# Processing Record 39 of Set 14 | taburi
# City not found. Skipping...
# Processing Record 40 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 41 of Set 14 | chernyakhiv
# Processing Record 42 of Set 14 | hailar
# Processing Record 43 of Set 14 | bartica
# Processing Record 44 of Set 14 | sokolo
# Processing Record 45 of Set 14 | la libertad
# Processing Record 46 of Set 14 | aykhal
# Processing Record 47 of Set 14 | la primavera
# Processing Record 48 of Set 14 | coihaique
# Processing Record 49 of Set 14 | limbe
# Processing Record 50 of Set 14 | coruripe
# Processing Record 1 of Set 15 | daru
# Processing Record 2 of Set 15 | ardistan
# City not found. Skipping...
# Processing Record 3 of Set 15 | ferrol
# Processing Record 4 of Set 15 | barabai
# Processing Record 5 of Set 15 | nova gradiska
# Processing Record 6 of Set 15 | pemba
# Processing Record 7 of Set 15 | dicabisagan
# Processing Record 8 of Set 15 | mananjary
# Processing Record 9 of Set 15 | jamsa
# Processing Record 10 of Set 15 | abalak
# Processing Record 11 of Set 15 | salinopolis
# Processing Record 12 of Set 15 | caravelas
# Processing Record 13 of Set 15 | wilmington
# Processing Record 14 of Set 15 | sungairaya
# Processing Record 15 of Set 15 | lumeje
# Processing Record 16 of Set 15 | gudalur
# Processing Record 17 of Set 15 | qasigiannguit
# Processing Record 18 of Set 15 | ketchikan
# Processing Record 19 of Set 15 | yurino
# Processing Record 20 of Set 15 | nokaneng
# Processing Record 21 of Set 15 | jizan
# Processing Record 22 of Set 15 | bangolo
# Processing Record 23 of Set 15 | pangai
# Processing Record 24 of Set 15 | west wendover
# Processing Record 25 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 26 of Set 15 | shubarkuduk
# Processing Record 27 of Set 15 | lazarev
# Processing Record 28 of Set 15 | cumana
# Processing Record 29 of Set 15 | rantepao
# Processing Record 30 of Set 15 | shu
# Processing Record 31 of Set 15 | novyy urgal
# Processing Record 32 of Set 15 | daye
# Processing Record 33 of Set 15 | poum
# Processing Record 34 of Set 15 | litovko
# Processing Record 35 of Set 15 | namanyere
# Processing Record 36 of Set 15 | salinas
# Processing Record 37 of Set 15 | bayir
# Processing Record 38 of Set 15 | springdale
# Processing Record 39 of Set 15 | komsomolskiy
# Processing Record 40 of Set 15 | kysyl-syr
# Processing Record 41 of Set 15 | irece
# Processing Record 42 of Set 15 | prudy
# Processing Record 43 of Set 15 | pinar del rio
# Processing Record 44 of Set 15 | la maddalena
# Processing Record 45 of Set 15 | haimen
# Processing Record 46 of Set 15 | naze
# Processing Record 47 of Set 15 | mbandaka
# Processing Record 48 of Set 15 | huangzhai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 693

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Tuktoyaktuk  69.4541 -133.0374      5.00        72         100       13.80
# 1      Rikitea -23.1203 -134.9692     78.33        76          11       13.53
# 2     Bengkulu  -3.8004  102.2655     73.90        89         100        3.53
# 3     Klaksvik  62.2266   -6.5890     43.72        90          85       18.28
# 4      Dolores -36.3132  -57.6792     86.20        22         100       18.88
# 5      Paamiut  61.9940  -49.6678      9.64        61         100        8.52
# 6        Vaini -21.2000 -175.2000     78.96        83          75        8.05
# 7    Jamestown  42.0970  -79.2353     57.02        67         100        5.75
# 8  New Norfolk -42.7826  147.0587     53.92        74          82        0.96
# 9       Hobart -42.8794  147.3294     54.27        80          75        4.61
#
#   Country Current Description
# 0      CA     overcast clouds
# 1      PF          few clouds
# 2      ID     overcast clouds
# 3      FO     overcast clouds
# 4      AR     overcast clouds
# 5      GL     overcast clouds
# 6      TO       broken clouds
# 7      US          light rain
# 8      AU       broken clouds
# 9      AU       broken clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Tuktoyaktuk      CA  69.4541 -133.0374      5.00        72         100
# 1      Rikitea      PF -23.1203 -134.9692     78.33        76          11
# 2     Bengkulu      ID  -3.8004  102.2655     73.90        89         100
# 3     Klaksvik      FO  62.2266   -6.5890     43.72        90          85
# 4      Dolores      AR -36.3132  -57.6792     86.20        22         100
# 5      Paamiut      GL  61.9940  -49.6678      9.64        61         100
# 6        Vaini      TO -21.2000 -175.2000     78.96        83          75
# 7    Jamestown      US  42.0970  -79.2353     57.02        67         100
# 8  New Norfolk      AU -42.7826  147.0587     53.92        74          82
# 9       Hobart      AU -42.8794  147.3294     54.27        80          75
#
#    Wind Speed Current Description
# 0       13.80     overcast clouds
# 1       13.53          few clouds
# 2        3.53     overcast clouds
# 3       18.28     overcast clouds
# 4       18.88     overcast clouds
# 5        8.52     overcast clouds
# 6        8.05       broken clouds
# 7        5.75          light rain
# 8        0.96       broken clouds
# 9        4.61       broken clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = './WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label='City_ID')
